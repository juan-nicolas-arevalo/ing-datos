# %% [markdown]
# <table>
#     <tr>
#         <td><img src="https://raw.githubusercontent.com/Fabian830348/Bases_Datos/refs/heads/master/logo_ECI.png" width="300"/></td>
#         <td>&nbsp;</td>
#         <td>
#             <h1 style="font-size:200%;color:blue;text-align:center">    <FONT COLOR="blue">  Tarea Corte 1   </p> Exploración de Datos </FONT>         </h1></td>
#         <td>
#             <tp><p style="font-size:99%;text-align:center">Aprendizaje Automático de Máquina </p></tp>
#             <tp><p style="font-size:115%;text-align:center">Pregrado MACC 2026-2</p></tp>
#             <tp><p style="font-size:115%;text-align:center">Prof. Fabián Sánchez</p></tp>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # <FONT SIZE=5 COLOR="purple"> **Indicaciones** </FONT>
#
# - Para entregar en grupos de tres integrantes únicamente.
#
# - **Importante:** Cargar en la plataforma *e-aulas* los **dos** archivos: ***.ipynb*** y ***.pdf***
#
# - Fecha de entrega el día **viernes 14 de agosto 6:00 p.m.**
#
# - Para mejorar el estilo de las gráficas, use comandos de edición (colores, títulos, etc.). Utilice las librerías matplotlib y seaborn

# %% [markdown]
# # <FONT SIZE=5 COLOR="purple"> Punto 1 </FONT>
#
# 1. Cargue el conjunto de datos denominado **homicidios**
# ```python
# https://raw.githubusercontent.com/Fabian830348/Bases_Datos/refs/heads/master/homicidios.csv
# ```
# 2. Haga una exploración rápida de los datos usando las funciones vistas en clase.
#
# 3. Identifique si hay datos faltantes. En caso positivo,  elimínelos.
#
# 4. Realice un gráfico de barras con la variable *Estado Civil*. Interprete
#
# 5. Realice un histograma con la variable *edad*. Interprete.
#
# 6. Realice un boxplot de la variable *edad* teniendo en cuenta la variable categórica: *estado civil*. Interprete.
#
# 7. Realice una tabla de contingencia entre las variables: *estado civil* y *arma empleada*.
#
# 8. Responda las siguientes preguntas.
#
#   - ¿Cuántas personas de sexo femenino, solteras fueron asesinadas con arma de fuego?
#
#   - ¿Cuántas personas fueron ultimadas por agresores en motocicleta?
#
#   - ¿Cuántas personas asesinadas por arma cortopunsante, son solteras y desempleadas?
#
#   - ¿Cuál es el Departamento que registra mayor número de asesinatos? discrimine por sexo y estado civil.

# %% [markdown]
# # <FONT SIZE=5 COLOR="purple"> Punto 2 </FONT>
#
# 1. Importe el conjunto de datos **actividad**
#
# Información de los datos : https://www.geriatic.udc.es/el-proyecto/datos-abiertos-open-data-del-proyecto-geria-tic/
#
# ```python
# https://raw.githubusercontent.com/Fabian830348/Bases_Datos/refs/heads/master/actividad.csv
# ```
# 2. Explore los datos rápidamente. ¿Hay datos faltantes?
#
# 3. Analice la variable *step*. Utilice un histograma y un boxplot para hacer el análisis.
#
# 4. De la variable *step* identifique los datos atípicos. Interprete
#
# 5. Hay un *userID* que es atípico a los demás. ¿Lo puede identificar?
#
# 6. Identifique los datos atípicos de la variable *step* del usuario *10036* y:
#
#   a. Elimínelos
#
#   b. Reemplácelos por la media.
#
#   c. Reemplácelos por la mediana
#
#   d. Calcule la media, la mediana, la desviación estándar de la variable en cada caso a., b. c. Compare los resultados. ¿Cuáles valores se ven más afectados? Concluya.
#
# | Tratamiento de los datos    | Media ($\mu$) | Mediana ($Q_2$) | Desviación estándar ($\sigma$) |
# | --------------------------- | :---: | :-----: | :-----------------: |
# | Con datos atípicos          |  ---  |   ---   |         ---         |
# | Eliminando datos atípicos                 |  ---  |   ---   |         ---         |
# | Reemplazándolos por la media   |  ---  |   ---   |         ---         |
# | Reemplazándolos por la mediana |  ---  |   ---   |         ---         |
